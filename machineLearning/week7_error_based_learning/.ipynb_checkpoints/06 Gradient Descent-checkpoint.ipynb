# %% [markdown]
# ## Gradient Descent
# The standard linear regression solver in `sklearn` uses a closed form solution to find the parameters (using matrix operations), see: https://towardsdatascience.com/closed-form-solution-to-linear-regression-e1fe14c1cbef#:~:text=In%20machine%20learning%2C%20we're,variable%20we're%20optimizing%20on
# However, `sklearn` aslo includes a (Stochastic) Gradient Descent implementation.

# %%
import pandas as pd
from sklearn.linear_model import SGDRegressor
weight_pd = pd.read_csv('data/weightV2.csv')
weight_pd.head()
# Out:
#    Weight  Waist
# 0  154.25   85.2
# 1  173.25   83.0
# 2  154.00   87.9
# 3  184.75   86.4
# 4  184.25  100.0

# %%
y = weight_pd.pop('Weight').values
X = weight_pd.values
X.shape
# Out:
# (251, 1)

# %% [markdown]
# It is important to scale data before using SGD

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)  
X = scaler.transform(X)

# %%
iters =range(1,7) # We look at the first 6 iterations of the GD process

# %% [markdown]
# The strategy is to run SGD multiple times with 1, then 2 then 3 iterations etc.
# The warning messages are because the algorithm is not getting to converge.

# %%
slopes = [None]
intercepts = [None]
rsq = [None]

for i in iters:
    reg = SGDRegressor(max_iter=i).fit(X, y)
    slopes.append(reg.coef_[0])
    intercepts.append(reg.intercept_[0])
    rsq.append(reg.score(X, y))
    print(' R squared statistic: {:.2f}'.format(rsq[i]))
    print(' Slope: {:.2f}'.format(slopes[i]))
    print(' Intercept: {:.2f}'.format(intercepts[i]))
# Out:
#  R squared statistic: -7.49
#  Slope: 14.70
#  Intercept: 101.18
#  R squared statistic: -1.92
#  Slope: 16.51
#  Intercept: 134.56
#  R squared statistic: -0.20
#  Slope: 20.52
#  Intercept: 151.93
#  R squared statistic: 0.37
#  Slope: 21.04
#  Intercept: 161.55
#  R squared statistic: 0.60
#  Slope: 22.36
#  Intercept: 167.46
#  R squared statistic: 0.69
#  Slope: 22.67
#  Intercept: 171.04
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/mauricio.reis/.pyenv/versions/3.9.9/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1549: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
slopes
# Out:
# [None,
#  13.90904460215465,
#  18.853185533976887,
#  19.571453021935366,
#  21.813097891932284,
#  21.977423817265468,
#  22.48381204881232]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
Y_pred = reg.predict(X)

plt.scatter(X, y, s = 10)
plt.plot(X, Y_pred, color='red')
plt.xlabel('Waist')
plt.ylabel('Weight')
plt.title ('Weight v Waist with Regression Line' )
plt.show()

# %% [markdown]
# ### Plot the progress of the SGD through the solution space
# The model has two parameters (slope and intercept) so we have a 2D solution space.
# Ok, we are restarting the SGD multiple times so this is not a true SGD track.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(slopes, intercepts)
plt.scatter(slopes, intercepts, s = 10)
plt.xlabel('Slopes')
plt.ylabel('Intercepts')
plt.title ('Slope v Intercept - convergence' )
plt.show()

# %% [markdown]
# ### Plot progress through the parameter space and the associated model

# %%
# A function to calculate two y values for two values of x - used in the plots.
def lin_reg(s,ic,x1,x2):
    y1 = ic + s * x1
    y2 = ic + s * x2
    return y1,y2

# %%
for step in iters:
    print(slopes[step],intercepts[step])
# Out:
# 14.702824636984095 101.17621660491731
# 16.508623956102575 134.564651177617
# 20.520949572446565 151.93216661064406
# 21.037736552737424 161.5472856828377
# 22.3645504057026 167.45789598284068
# 22.674048013796593 171.04071049282973

# %%
x_min = -2.4
x_max = 3.4
x_lims = [12,23]
y_lims = [90,180]

fig = plt.figure(figsize=(8,20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
i = 0
for step in iters:
    i += 1
    ax1 = fig.add_subplot(len(iters), 2, i)
    ax1.plot(slopes[:step+1], intercepts[:step+1])
    ax1.scatter(slopes[:step+1], intercepts[:step+1], s = 10)
    ax1.set_xlabel('Slope')
    ax1.set_ylabel('Intercept')
    ax1.set_xlim(x_lims)
    ax1.set_ylim(y_lims)

    i += 1
    ax2 = fig.add_subplot(len(iters), 2, i)
    ax2.scatter(X, y, s = 10)
    ax2.set_xlabel('Waist')
    ax2.set_ylabel('Weight')
    y1,y2 = lin_reg(slopes[step],intercepts[step], x_min, x_max)
    ax2.plot([x_min, x_max], [y1,y2], color='red')

# %% [markdown]
# ## Random Guessing

# %%
from random import uniform
x_min = -2.4
x_max = 3.4
x_lims = [12,23]
y_lims = [90,180]

# %%
slopes = [None]
intercepts = [None]

for i in iters:
    s = uniform(-x_lims[1],x_lims[1])
    intcp = uniform(y_lims[0],y_lims[1])
  
    slopes.append(s)
    intercepts.append(intcp)
    print(' Slope: {:.2f}'.format(slopes[i]))
    print(' Intercept: {:.2f}'.format(intercepts[i]))
# Out:
#  Slope: -5.01
#  Intercept: 124.41
#  Slope: 10.29
#  Intercept: 173.81
#  Slope: 10.25
#  Intercept: 121.91
#  Slope: -19.16
#  Intercept: 154.41
#  Slope: 10.66
#  Intercept: 177.99
#  Slope: 18.91
#  Intercept: 120.80

# %%
fig = plt.figure(figsize=(8,20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
i = 0
for step in iters:
    i += 1
    ax1 = fig.add_subplot(len(iters), 2, i)
    ax1.plot(slopes[:step+1], intercepts[:step+1])
    ax1.scatter(slopes[:step+1], intercepts[:step+1], s = 10)
    ax1.set_xlabel('Slope')
    ax1.set_ylabel('Intercept')
    ax1.set_xlim(-x_lims[1],x_lims[1])
    ax1.set_ylim(y_lims)

    i += 1
    ax2 = fig.add_subplot(len(iters), 2, i)
    ax2.scatter(X, y, s = 10)
    ax2.set_xlabel('Waist')
    ax2.set_ylabel('Weight')
    y1,y2 = lin_reg(slopes[step],intercepts[step], x_min, x_max)
    ax2.plot([x_min, x_max], [y1,y2], color='red')
